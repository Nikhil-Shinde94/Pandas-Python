# %%
#Import the necessary libraries

import numpy as np
import pandas as pd

# %%
#Import the dataset from this address.

url = 'https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv'

# %%
chipo = pd.read_csv(url, sep='\t')

# %%
chipo.head()
# Out:
#    order_id  ...  item_price
# 0         1  ...      $2.39
# 1         1  ...      $3.39
# 2         1  ...      $3.39
# 3         1  ...      $2.39
# 4         2  ...     $16.98
#
# [5 rows x 5 columns]

# %%
#How many products cost more than $10.00?

prices = [float(value[1 : -1]) for value in chipo.item_price]

chipo.item_price = prices

# %%
chipo_filtered_item_price = chipo.drop_duplicates(['item_name','quantity'])

# %%
chipo_one_product = chipo_filtered_item_price[chipo.quantity == 1]
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.

# %%
chipo_one_product[chipo_one_product['item_price']>10].item_name.nunique()
# Out:
# 12

# %%
#What is the price of each item?

chipo_new_df = chipo[['item_name','item_price']]

# %%
chipo_new_df.item_name.value_counts([chipo['quantity']==1])
# Out:
# Chicken Bowl                             0.157075
# Chicken Burrito                          0.119645
# Chips and Guacamole                      0.103635
# Steak Burrito                            0.079619
# Canned Soft Drink                        0.065123
# Steak Bowl                               0.045651
# Chips                                    0.045651
# Bottled Water                            0.035050
# Chicken Soft Tacos                       0.024881
# Chips and Fresh Tomato Salsa             0.023799
# Chicken Salad Bowl                       0.023799
# Canned Soda                              0.022501
# Side of Chips                            0.021852
# Veggie Burrito                           0.020554
# Barbacoa Burrito                         0.019688
# Veggie Bowl                              0.018390
# Carnitas Bowl                            0.014712
# Barbacoa Bowl                            0.014280
# Carnitas Burrito                         0.012765
# ...

# %%
_chipo_filtered_item_price = chipo.drop_duplicates(['item_name','quantity'])

# %%
chipo[(chipo['item_name'] == 'Chips and Fresh Tomato Salsa') & (chipo['quantity'] == 1)]
# Out:
#       order_id  quantity  ... choice_description item_price
# 0            1         1  ...                NaN       2.39
# 25          13         1  ...                NaN       2.39
# 55          25         1  ...                NaN       2.39
# 89          39         1  ...                NaN       2.95
# 183         82         1  ...                NaN       2.95
# ...        ...       ...  ...                ...        ...
# 4231      1689         1  ...                NaN       2.95
# 4318      1722         1  ...                NaN       2.95
# 4324      1725         1  ...                NaN       2.95
# 4425      1764         1  ...                NaN       2.95
# 4503      1790         1  ...                NaN       2.95
#
# [105 rows x 5 columns]

# %%
dff = chipo_new_df.sort_values(by='item_price', ascending=True)

# %%
dff.groupby(by=(chipo['quantity'] == 1))

# %%
dff
# Out:
#                          item_name  item_price
# 1140                 Bottled Water        1.09
# 821                    Canned Soda        1.09
# 3926                   Canned Soda        1.09
# 107                    Canned Soda        1.09
# 2562                   Canned Soda        1.09
# ...                            ...         ...
# 3601                Veggie Burrito       33.75
# 3602               Chicken Burrito       35.00
# 1254               Chicken Burrito       35.00
# 3480                 Carnitas Bowl       35.25
# 3598  Chips and Fresh Tomato Salsa       44.25
#
# [4622 rows x 2 columns]

# %%
dff.item_name.unique()
# Out:
# array(['Bottled Water', 'Canned Soda', 'Canned Soft Drink',
#        'Side of Chips', 'Chips', 'Chips and Fresh Tomato Salsa',
#        'Chips and Roasted Chili-Corn Salsa',
#        'Chips and Tomatillo-Green Chili Salsa',
#        'Chips and Tomatillo-Red Chili Salsa',
#        'Chips and Tomatillo Red Chili Salsa',
#        'Chips and Roasted Chili Corn Salsa',
#        'Chips and Tomatillo Green Chili Salsa',
#        'Chips and Mild Fresh Tomato Salsa', 'Nantucket Nectar', 'Izze',
#        'Chips and Guacamole', '6 Pack Soft Drink', 'Burrito', 'Bowl',
#        'Salad', 'Crispy Tacos', 'Chicken Bowl', 'Chicken Burrito',
#        'Chicken Salad', 'Veggie Burrito', 'Chicken Soft Tacos',
#        'Chicken Crispy Tacos', 'Veggie Salad', 'Veggie Bowl',
#        'Veggie Soft Tacos', 'Veggie Crispy Tacos', 'Steak Burrito',
#        'Steak Bowl', 'Barbacoa Burrito', 'Barbacoa Bowl', 'Steak Salad',
#        'Carnitas Burrito', 'Steak Crispy Tacos', 'Chicken Salad Bowl',
# ...

# %%
def Kickstarter_Example_92():
    print()
    print(format('How to list unique values in a Pandas DataFrame','*^82'))

    import warnings
    warnings.filterwarnings("ignore")

    pd.set_option('display.max_row', 1000)

    pd.set_option('display.max_columns', 50)

    data = chipo_new_df

    df_2 = pd.DataFrame(data, index = ['item_price', 'item_name'])

    print(); print(df_2)

    print(); print(df_2.item_name.unique())

# %%
Kickstarter_Example_92()
# Out:
# *****************How to list unique values in a Pandas DataFrame******************
#
#            item_name  item_price
# item_price       NaN         NaN
# item_name        NaN         NaN
#
# [nan]

# %%
#Sort by the name of the item

chipo.item_name.sort_values()
# Out:
# 3389    6 Pack Soft Drink
# 341     6 Pack Soft Drink
# 1849    6 Pack Soft Drink
# 1860    6 Pack Soft Drink
# 2713    6 Pack Soft Drink
#               ...
# 2384    Veggie Soft Tacos
# 781     Veggie Soft Tacos
# 2851    Veggie Soft Tacos
# 1699    Veggie Soft Tacos
# 1395    Veggie Soft Tacos
# Name: item_name, Length: 4622, dtype: object

# %%
# What was the quantity of the most expensive item ordered?

chipo.quantity.sort_values(ascending=False)
# Out:
# 3598    15
# 4152    10
# 3887     8
# 3599     7
# 2441     5
#         ..
# 3023     1
# 3022     1
# 3021     1
# 3020     1
# 0        1
# Name: quantity, Length: 4622, dtype: int64

# %%
chipo.sort_values(by='quantity', ascending=False)
# Out:
#       order_id  quantity                              item_name  \
# 3598      1443        15           Chips and Fresh Tomato Salsa
# 4152      1660        10                          Bottled Water
# 3887      1559         8                          Side of Chips
# 3599      1443         7                          Bottled Water
# 2441       970         5                          Bottled Water
# ...        ...       ...                                    ...
# 1592       645         1                           Chicken Bowl
# 1593       645         1  Chips and Tomatillo Green Chili Salsa
# 1594       646         1                          Carnitas Bowl
# 1595       646         1                        Chicken Burrito
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description  item_price
# 3598                                                NaN       44.25
# ...

# %%
#How many times were a Veggie Salad Bowl ordered?

len(chipo[chipo.item_name == 'Veggie Salad Bowl'])
# Out:
# 18

# %%
#How many times people orderd more than one Canned Soda?

len(chipo[chipo.item_name == 'Canned Soda'])
# Out:
# 104
