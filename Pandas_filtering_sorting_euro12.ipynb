# %%
import pandas as pd
import numpy as np

# %%
url = 'https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/02_Filtering_%26_Sorting/Euro12/Euro_2012_stats_TEAM.csv'

# %%
euro12 = pd.read_csv(url, sep=',')

# %%
euro12.head()
# Out:
#              Team  Goals  Shots on target  ...  Subs on Subs off Players Used
# 0         Croatia      4               13  ...        9        9           16
# 1  Czech Republic      4               13  ...       11       11           19
# 2         Denmark      4               10  ...        7        7           15
# 3         England      5               11  ...       11       11           16
# 4          France      3               22  ...       11       11           19
#
# [5 rows x 35 columns]

# %%
#Select only the Goal column.

euro12.Goals
# Out:
# 0      4
# 1      4
# 2      4
# 3      5
# 4      3
# 5     10
# 6      5
# 7      6
# 8      2
# 9      2
# 10     6
# 11     1
# 12     5
# 13    12
# 14     5
# 15     2
# Name: Goals, dtype: int64

# %%
#How many team participated in the Euro2012?

euro12.Team.count()
# Out:
# 16

# %%
#What is the number of columns in the dataset?

len(euro12.columns)
# Out:
# 35

# %%
#View only the columns Team, Yellow Cards and Red Cards and assign them to a dataframe called discipline

discipline = euro12[['Team','Yellow Cards', 'Red Cards']]

# %%
discipline.head()
# Out:
#              Team  Yellow Cards  Red Cards
# 0         Croatia             9          0
# 1  Czech Republic             7          0
# 2         Denmark             4          0
# 3         England             5          0
# 4          France             6          0

# %%
#Sort the teams by Red Cards, then to Yellow Cards

discipline.sort_values(['Yellow Cards','Red Cards'], ascending=False)
# Out:
#                    Team  Yellow Cards  Red Cards
# 7                 Italy            16          0
# 10             Portugal            12          0
# 13                Spain            11          0
# 6                Greece             9          1
# 0               Croatia             9          0
# 9                Poland             7          1
# 1        Czech Republic             7          0
# 14               Sweden             7          0
# 11  Republic of Ireland             6          1
# 4                France             6          0
# 12               Russia             6          0
# 3               England             5          0
# 8           Netherlands             5          0
# 15              Ukraine             5          0
# 2               Denmark             4          0
# 5               Germany             4          0

# %%
#Calculate the mean Yellow Cards given per Team

euro12['Yellow Cards'].mean()
# Out:
# 7.4375

# %%
#Filter teams that scored more than 6 goals

euro12[euro12['Goals'] >= 6]
# Out:
#         Team  Goals  Shots on target  ...  Subs on Subs off Players Used
# 5    Germany     10               32  ...       15       15           17
# 7      Italy      6               34  ...       18       18           19
# 10  Portugal      6               22  ...       14       14           16
# 13     Spain     12               42  ...       17       17           18
#
# [4 rows x 35 columns]

# %%
#Select the teams that start with G

euro12['Team'].str.startswith('G')
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5      True
# 6      True
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# Name: Team, dtype: bool

# %%
euro12[euro12['Team'].str.startswith('G')]
# Out:
#       Team  Goals  Shots on target  ...  Subs on Subs off Players Used
# 5  Germany     10               32  ...       15       15           17
# 6   Greece      5                8  ...       12       12           20
#
# [2 rows x 35 columns]

# %%
#Select the first 7 columns

euro12.iloc[:,0:7]
# Out:
#                    Team  Goals  ...  % Goals-to-shots  Total shots (inc. Blocked)
# 0               Croatia      4  ...             16.0%                          32
# 1        Czech Republic      4  ...             12.9%                          39
# 2               Denmark      4  ...             20.0%                          27
# 3               England      5  ...             17.2%                          40
# 4                France      3  ...              6.5%                          65
# 5               Germany     10  ...             15.6%                          80
# 6                Greece      5  ...             19.2%                          32
# 7                 Italy      6  ...              7.5%                         110
# 8           Netherlands      2  ...              4.1%                          60
# 9                Poland      2  ...              5.2%                          48
# ...

# %%
#Select all columns except the last 3.

euro12.iloc[:,:-3]
# Out:
#                    Team  Goals  ...  Yellow Cards  Red Cards
# 0               Croatia      4  ...             9          0
# 1        Czech Republic      4  ...             7          0
# 2               Denmark      4  ...             4          0
# 3               England      5  ...             5          0
# 4                France      3  ...             6          0
# 5               Germany     10  ...             4          0
# 6                Greece      5  ...             9          1
# 7                 Italy      6  ...            16          0
# 8           Netherlands      2  ...             5          0
# 9                Poland      2  ...             7          1
# 10             Portugal      6  ...            12          0
# 11  Republic of Ireland      1  ...             6          1
# 12               Russia      5  ...             6          0
# 13                Spain     12  ...            11          0
# ...

# %%
euro12.iloc[:, -3:]
# Out:
#     Subs on  Subs off  Players Used
# 0         9         9            16
# 1        11        11            19
# 2         7         7            15
# 3        11        11            16
# 4        11        11            19
# 5        15        15            17
# 6        12        12            20
# 7        18        18            19
# 8         7         7            15
# 9         7         7            17
# 10       14        14            16
# 11       10        10            17
# 12        7         7            16
# 13       17        17            18
# 14        9         9            18
# 15        9         9            18

# %%
euro12.iloc[:, [euro12.columns != ['Subs on',	'Subs off',	'Players Used']]]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-49-9601a582967b> in <module>()
# ----> 1 euro12.iloc[:, [euro12.loc != ['Subs on',       'Subs off',     'Players Used']]]
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/indexing.py in __getitem__(self, key)
#    1760                 except (KeyError, IndexError, AttributeError):
#    1761                     pass
# -> 1762             return self._getitem_tuple(key)
#    1763         else:
#    1764             # we by definition only have the 0th axis
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/indexing.py in _getitem_tuple(self, tup)
#    2078                 continue
#    2079
# -> 2080             retval = getattr(retval, self.name)._getitem_axis(key, axis=axis)
#    2081
#    2082             # if the dim was reduced, then pass a lower-dim the next time
#
# ...

# %%
#Present only the Shooting Accuracy from England, Italy and Russia

euro12.loc[euro12.Team.isin(['England', 'Italy', 'Russia']), ['Team','Shooting Accuracy']]
# Out:
#        Team Shooting Accuracy
# 3   England             50.0%
# 7     Italy             43.0%
# 12   Russia             22.5%

# %%
euro = euro12.iloc[:, :1]
euro.isin(['Engaland','Italy', 'Russia']).groupby(['Shooting Accuracy'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-61-d0dbe8c45013> in <module>()
#       1 euro = euro12.iloc[:, :1]
# ----> 2 euro.isin(['Engaland','Italy', 'Russia']).groupby(['Shooting Accuracy'])
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/frame.py in groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, observed)
#    5808             group_keys=group_keys,
#    5809             squeeze=squeeze,
# -> 5810             observed=observed,
#    5811         )
#    5812
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/groupby/groupby.py in __init__(self, obj, keys, axis, level, grouper, exclusions, selection, as_index, sort, group_keys, squeeze, observed, mutated)
#     408                 sort=sort,
#     409                 observed=observed,
# --> 410                 mutated=self.mutated,
#     411             )
#     412
#
# ...
