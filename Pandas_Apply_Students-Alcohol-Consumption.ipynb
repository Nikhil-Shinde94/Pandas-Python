# %%
import pandas as pd

# %%
df = pd.read_table('https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/04_Apply/Students_Alcohol_Consumption/student-mat.csv', sep=',')

# %%
df.head()
# Out:
#   school sex  age address famsize Pstatus  ...  Walc  health absences  G1  G2  G3
# 0     GP   F   18       U     GT3       A  ...     1       3        6   5   6   6
# 1     GP   F   17       U     GT3       T  ...     1       3        4   5   5   6
# 2     GP   F   15       U     LE3       T  ...     3       3       10   7   8  10
# 3     GP   F   15       U     GT3       T  ...     1       5        2  15  14  15
# 4     GP   F   16       U     GT3       T  ...     2       5        4   6  10  10
#
# [5 rows x 33 columns]

# %%
#For the purpose of this exercise slice the dataframe from 'school' until the 'guardian' column

df.iloc[:, 0:16]
# Out:
#     school sex  age address  ... traveltime studytime  failures  schoolsup
# 0       GP   F   18       U  ...          2         2         0        yes
# 1       GP   F   17       U  ...          1         2         0         no
# 2       GP   F   15       U  ...          1         2         3        yes
# 3       GP   F   15       U  ...          1         3         0         no
# 4       GP   F   16       U  ...          1         2         0         no
# ..     ...  ..  ...     ...  ...        ...       ...       ...        ...
# 390     MS   M   20       U  ...          1         2         2         no
# 391     MS   M   17       U  ...          2         1         0         no
# 392     MS   M   21       R  ...          1         1         3         no
# 393     MS   M   18       R  ...          3         1         0         no
# 394     MS   M   19       U  ...          1         1         0         no
#
# [395 rows x 16 columns]

# %%
#Create a lambda function that capitalize strings.

capitalizer = lambda x: x.capitalize()

# %%
#Capitalize both Mjob and Fjob

df['Mjob'].apply(capitalizer)
df['Fjob'].apply(capitalizer)
# Out:
# 0       Teacher
# 1         Other
# 2         Other
# 3      Services
# 4         Other
#          ...
# 390    Services
# 391    Services
# 392       Other
# 393       Other
# 394     At_home
# Name: Fjob, Length: 395, dtype: object

# %%
#Print the last elements of the data set.

df.iloc[-1:, :]
# Out:
#     school sex  age address famsize Pstatus  ...  Walc  health absences G1 G2 G3
# 394     MS   M   19       U     LE3       T  ...     3       5        5  8  9  9
#
# [1 rows x 33 columns]

# %%
#Did you notice the original dataframe is still lowercase? Why is that? Fix it and capitalize Mjob and Fjob.

#df['Mjob'] = map(lambda x: x.capitalize(), df['Mjob'])
#print(df['Mjob'])

# %%
df['Mjob'] = df['Mjob'].apply(capitalizer)
df['Fjob'] = df['Fjob'].apply(capitalizer)
df.tail()
# Out:
#     school sex  age address famsize Pstatus  ...  Walc  health absences  G1  G2  G3
# 390     MS   M   20       U     LE3       A  ...     5       4       11   9   9   9
# 391     MS   M   17       U     LE3       T  ...     4       2        3  14  16  16
# 392     MS   M   21       R     GT3       T  ...     3       3        3  10   8   7
# 393     MS   M   18       R     LE3       T  ...     4       5        0  11  12  10
# 394     MS   M   19       U     LE3       T  ...     3       5        5   8   9   9
#
# [5 rows x 33 columns]

# %%
#Create a function called majority that return a boolean value to a new column called legal_drinker (Consider majority as older than 17 years old)

def majority(x):
  if x> 17:
    return True
  else:
    return False

# %%
df['legal_drinker'] = df['age'].apply(majority)
df.head()
# Out:
#   school sex  age address famsize  ... absences  G1  G2  G3 legal_drinker
# 0     GP   F   18       U     GT3  ...        6   5   6   6          True
# 1     GP   F   17       U     GT3  ...        4   5   5   6         False
# 2     GP   F   15       U     LE3  ...       10   7   8  10         False
# 3     GP   F   15       U     GT3  ...        2  15  14  15         False
# 4     GP   F   16       U     GT3  ...        4   6  10  10         False
#
# [5 rows x 34 columns]

# %%
#Multiply every number of the dataset by 10.

def times10(x):
  if type(x) is int:
    return 10 * x
  return x

# %%
df.applymap(times10).head(10)
# Out:
#   school sex  age address famsize  ... absences   G1   G2   G3 legal_drinker
# 0     GP   F  180       U     GT3  ...       60   50   60   60          True
# 1     GP   F  170       U     GT3  ...       40   50   50   60         False
# 2     GP   F  150       U     LE3  ...      100   70   80  100         False
# 3     GP   F  150       U     GT3  ...       20  150  140  150         False
# 4     GP   F  160       U     GT3  ...       40   60  100  100         False
# 5     GP   M  160       U     LE3  ...      100  150  150  150         False
# 6     GP   M  160       U     LE3  ...        0  120  120  110         False
# 7     GP   F  170       U     GT3  ...       60   60   50   60         False
# 8     GP   M  150       U     LE3  ...        0  160  180  190         False
# 9     GP   M  150       U     GT3  ...        0  140  150  150         False
#
# [10 rows x 34 columns]
