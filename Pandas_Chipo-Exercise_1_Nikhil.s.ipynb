# %%
#Step 1. Import the necessary libraries

import numpy as np
import pandas as pd

# %%
#Import the dataset from this your system
df = pd.read_csv('/content/Chipotle - Chipotle.csv', na_values=[' ?'])

# %%
#Assign it to a variable called chipo.

chipo = df

# %%
#See the first 10 entries
chipo.head(10)
# Out:
#    order_id  ...  item_price
# 0         1  ...       $2.39
# 1         1  ...       $3.39
# 2         1  ...       $3.39
# 3         1  ...       $2.39
# 4         2  ...      $16.98
# 5         3  ...      $10.98
# 6         3  ...       $1.69
# 7         4  ...      $11.75
# 8         4  ...       $9.25
# 9         5  ...       $9.25
#
# [10 rows x 5 columns]

# %%
#What is the number of observations in the dataset?

chipo.shape
# Out:
# (4622, 5)

# %%
chipo.count()
# Out:
# order_id              4622
# quantity              4622
# item_name             4622
# choice_description    3376
# item_price            4622
# dtype: int64

# %%
#What is the number of columns in the dataset?
print("Number of Columns in the Dataset is : ", len(chipo.columns))
#len(chipo.columns)
# Out:
# Number of Columns in the Dataset is :  5

# %%
#Print the name of all the columns.
chipo.columns
# Out:
# Index(['order_id', 'quantity', 'item_name', 'choice_description',
#        'item_price'],
#       dtype='object')

# %%
#How is the dataset indexed?

chipo.index
# Out:
# RangeIndex(start=0, stop=4622, step=1)

# %%
#Which was the most-ordered item?

it = chipo.groupby('item_name')
it = it.sum()
it = it.sort_values(['quantity'], ascending=False)
it.head(10)
# Out:
#                               order_id  quantity
# item_name
# Chicken Bowl                    713926       761
# Chicken Burrito                 497303       591
# Chips and Guacamole             449959       506
# Steak Burrito                   328437       386
# Canned Soft Drink               304753       351
# Chips                           208004       230
# Steak Bowl                      193752       221
# Bottled Water                   175944       211
# Chips and Fresh Tomato Salsa    100419       130
# Canned Soda                      76396       126

# %%
#from dataprep.eda import correlation
#plot_correlation(df)

# %%
#For the most-ordered item, how many items were ordered

items = chipo.groupby('item_name')
items = items.sum()
items = items.sort_values(['quantity'], ascending=False)
items.head(10)
# Out:
#                               order_id  quantity
# item_name
# Chicken Bowl                    713926       761
# Chicken Burrito                 497303       591
# Chips and Guacamole             449959       506
# Steak Burrito                   328437       386
# Canned Soft Drink               304753       351
# Chips                           208004       230
# Steak Bowl                      193752       221
# Bottled Water                   175944       211
# Chips and Fresh Tomato Salsa    100419       130
# Canned Soda                      76396       126

# %%
#What was the most ordered item in the choice_description column?

items = chipo.groupby('choice_description')
items = items.sum()
items = items.sort_values(['quantity'], ascending=False)
items.head(10)
# Out:
#                                                     order_id  quantity
# choice_description
# [Diet Coke]                                           123455       159
# [Coke]                                                122752       143
# [Sprite]                                               80426        89
# [Fresh Tomato Salsa, [Rice, Black Beans, Cheese...     43088        49
# [Fresh Tomato Salsa, [Rice, Black Beans, Cheese...     36041        42
# [Fresh Tomato Salsa, [Rice, Black Beans, Cheese...     37550        40
# [Lemonade]                                             31892        36
# [Fresh Tomato Salsa (Mild), [Pinto Beans, Rice,...     24432        36
# [Coca Cola]                                            19282        32
# [Fresh Tomato Salsa, [Rice, Cheese, Sour Cream,...     29614        30

# %%
#How many items were orderd in total?

total_items = chipo.quantity.sum()
total_items
# Out:
# 4972

# %%
#Turn the item price into a float

chipo['item_price'] = chipo['item_price'].str.replace('$','')
#chipo['item_price'] = chipo['item_price'].astype('float')
#chipo['item_price'] = pd.to_numeric(chipo['item_price'], downcast='float')
#chipo['item_price'] = int(chipo['item_price'])

# %%
#Check the item price type

chipo.item_price.dtype
# Out:
# dtype('O')

# %%
#Create a lambda function and change the type of item price
#chipo['item_price'] = chipo['item_price'].apply(lambda x: type(x).__name__)

# %%
#Check the item price type
#chipo.item_price.dtype

# %%
chipo['item_price'] = chipo['item_price'].apply(lambda x: x.replace('$', ''))

# %%
chipo['item_price'].astype('float64')
# Out:
# 0        2.39
# 1        3.39
# 2        3.39
# 3        2.39
# 4       16.98
#         ...
# 4617    11.75
# 4618    11.75
# 4619    11.25
# 4620     8.75
# 4621     8.75
# Name: item_price, Length: 4622, dtype: float64

# %%
#How much was the revenue for the period in the dataset?
revenue = (qunt * chipo['item_price']).sum()

# %%
qunt = chipo['quantity'].astype('int64')

# %%
print(str(np.round(revenue,2)))
# Out:
# ---------------------------------------------------------------------------
# UFuncTypeError                            Traceback (most recent call last)
# <ipython-input-85-ed9f92d0f140> in <module>()
# ----> 1 print(str(np.round(revenue,2)))
#
# <__array_function__ internals> in round_(*args, **kwargs)
#
# /usr/local/lib/python3.6/dist-packages/numpy/core/fromnumeric.py in round_(a, decimals, out)
#    3597     around : equivalent function; see for details.
#    3598     """
# -> 3599     return around(a, decimals=decimals, out=out)
#    3600
#    3601
#
# <__array_function__ internals> in around(*args, **kwargs)
#
# /usr/local/lib/python3.6/dist-packages/numpy/core/fromnumeric.py in around(a, decimals, out)
#    3222
#    3223     """
# -> 3224     return _wrapfunc(a, 'round', decimals=decimals, out=out)
#    3225
#    3226
#
# /usr/local/lib/python3.6/dist-packages/numpy/core/fromnumeric.py in _wrapfunc(obj, method, *args, **kwds)
#      56     bound = getattr(obj, method, None)
# ...

# %%
#How many orders were made in the period?

chipo.order_id.value_counts().count()
# Out:
# 1834

# %%
#What is the average revenue amount per order?

chipo['newcolumn'] = chipo['quantity'] * chipo['item_price']

# %%
ordered = chipo.groupby(by=['order_id']).sum()

# %%
ordered.mean()
# Out:
# quantity    2.711014
# dtype: float64

# %%
chipo['newcolumn'].replace('16.9816.98', '16.9816')
# Out:
# 0          2.39
# 1          3.39
# 2          3.39
# 3          2.39
# 4       16.9816
#          ...
# 4617      11.75
# 4618      11.75
# 4619      11.25
# 4620       8.75
# 4621       8.75
# Name: newcolumn, Length: 4622, dtype: object

# %%
chipo['newcolumn'].mean()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /usr/local/lib/python3.6/dist-packages/pandas/core/nanops.py in _ensure_numeric(x)
#    1302         try:
# -> 1303             x = float(x)
#    1304         except ValueError:
#
# ...

# %%
#How many different items are sold?

chipo.item_name.value_counts().count()
# Out:
# 50
