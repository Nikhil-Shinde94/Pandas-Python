# %%
import pandas as pd
import numpy as np

# %%
#import requests

#download_url = "https://www.kaggle.com/openfoodfacts/world-food-facts/data?select=en.openfoodfacts.org.products.tsv"
#target_csv_path = "en.openfoodfacts.org.products.tsv"

# %%
#response = requests.get(download_url)
#response.raise_for_status()    # Check that the request was successful
#with open(target_csv_path, "wb") as f:
#    f.write(response.content)
#print("Download ready.")
# Out:
# Download ready.

# %%
#df = pd.read_csv('en.openfoodfacts.org.products.tsv', sep='\t')

# %%
#See the first 5 entries

#df.head()
# Out:
#                                      <!DOCTYPE html>
# 0                                   <html lang="en">
# 1                                             <head>
# 2            <title>Open Food Facts | Kaggle</title>
# 3                           <meta charset="utf-8" />
# 4      <meta name="robots" content="index, follow...

# %%
! pip install -q kaggle

from google.colab import files

files.upload()
# Out:
#      <input type="file" id="files-139105dc-1cbb-4c52-aa99-97cd30f57c1f" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-139105dc-1cbb-4c52-aa99-97cd30f57c1f">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving kaggle.json to kaggle (1).json
# {'kaggle.json': b'{"username":"shindenikhil","key":"815bd702473192ebf7c611487f7a8038"}'}

# %%
! mkdir ~/.kaggle
# Out:
# mkdir: cannot create directory ‘/root/.kaggle’: File exists

# %%
! cp kaggle.json ~/.kaggle/

# %%
! chmod 600 ~/.kaggle/kaggle.json

# %%
! kaggle datasets list
# Out:
# ...
# ref                                                           title                                                size  lastUpdated          downloadCount
# ------------------------------------------------------------  --------------------------------------------------  -----  -------------------  -------------
# allen-institute-for-ai/CORD-19-research-challenge             COVID-19 Open Research Dataset Challenge (CORD-19)    3GB  2020-07-06 18:49:31          86949
# roche-data-science-coalition/uncover                          UNCOVER COVID-19 Challenge                          179MB  2020-05-21 18:57:53          15205
# oleksastepaniuk/prozorro-public-procurement-dataset           ProZorro. Ukrainian public procurement dataset      448MB  2020-04-15 17:09:37             26
# navinmundhra/daily-power-generation-in-india-20172020         Daily Power Generation in India (2017-2020)          63KB  2020-06-29 17:13:29            262
# ...

# %%
# !kaggle datasets download -d openfoodfacts/world-food-facts
# Out:
# ...
#  89% 97.0M/109M [00:03<00:00, 26.4MB/s]
# 100% 109M/109M [00:03<00:00, 30.6MB/s]

# %%
df_food = pd.read_csv('world-food-facts.zip',compression='zip', header=0, sep='\t', quotechar='"')
# Out:
# /usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py:2718: DtypeWarning: Columns (0,3,5,19,20,24,25,26,27,28,36,37,38,39,48) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
#See the first 5 entries
df_food.head()
# Out:
#     code  ... water-hardness_100g
# 0   3087  ...                 NaN
# 1   4530  ...                 NaN
# 2   4559  ...                 NaN
# 3  16087  ...                 NaN
# 4  16094  ...                 NaN
#
# [5 rows x 163 columns]

# %%
#What is the number of observations in the dataset?

df_food.shape
# Out:
# (356027, 163)

# %%
#What is the number of columns in the dataset?

len(df_food.columns)
# Out:
# 163

# %%
#Print the name of all the columns.

df_food.columns
# Out:
# Index(['code', 'url', 'creator', 'created_t', 'created_datetime',
#        'last_modified_t', 'last_modified_datetime', 'product_name',
#        'generic_name', 'quantity',
#        ...
#        'fruits-vegetables-nuts_100g', 'fruits-vegetables-nuts-estimate_100g',
#        'collagen-meat-protein-ratio_100g', 'cocoa_100g', 'chlorophyl_100g',
#        'carbon-footprint_100g', 'nutrition-score-fr_100g',
#        'nutrition-score-uk_100g', 'glycemic-index_100g',
#        'water-hardness_100g'],
#       dtype='object', length=163)

# %%
#What is the name of 105th column?

df_food.columns[104]
# Out:
# '-glucose_100g'

# %%
#What is the type of the observations of the 105th column?

df_food['-glucose_100g'].dtype
# Out:
# dtype('float64')

# %%
#How is the dataset indexed?

df_food.index
# Out:
# RangeIndex(start=0, stop=356027, step=1)

# %%
#What is the product name of the 19th observation?

df_food['product_name'][18]
# Out:
# 'Lotus Organic Brown Jasmine Rice'
